# %% [markdown]
# # PLANTILLA MODELIZACIÓN PARA REGRESIÓN

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# **IMPORTANTE**: Esta plantilla está diseñada para una visión de máximos utilizando el framework de The Ultimate Algo Machine. Si tienes problemas de memoria o rendimiento recuerda reducir el problema mediante:
#
# * Muestreo
# * Balanceo undersampling
# * Reducir el número de algoritmos a testar
# * Reducir el número de parámetros a testar
# * Usar random search y especificar un n_iter adecuado

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_absolute_percentage_error

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = ruta_proyecto = 'C:/proyectos/weather_ohio/'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %% [markdown]
# Cargar los datos.

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %%
y
# Out:
# DATE
# 1998-04-04    8.33
# 1998-04-05   12.22
# 1998-04-07   16.67
# 1998-04-08   21.11
# 1998-04-09   17.22
#               ...
# 2021-12-27   15.00
# 2021-12-28   11.67
# 2021-12-29   10.00
# 2021-12-30   13.33
# 2021-12-31   13.33
# Name: target, Length: 8665, dtype: float64

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %%
train_x.shape,train_y.shape
# Out:
# ((6065, 10), (6065,))

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
pipe = Pipeline([('algoritmo',RandomForestRegressor())])

grid = [{'algoritmo': [LinearRegression()],
         'algoritmo__n_jobs': [-1]},
        
        {'algoritmo': [RandomForestRegressor()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__max_depth': [5,10,15],
         'algoritmo__n_estimators': [50,100,200]},
        
        {'algoritmo': [XGBRegressor()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
         'algoritmo__max_depth': [5,10,20],
         'algoritmo__reg_alpha': [0,0.1,0.5,1],
         'algoritmo__reg_lambda': [0.01,0.1,1],
         'algoritmo__n_estimators': [100,500,1000]}
        ,
        {'algoritmo': [HistGradientBoostingRegressor()],
         'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
         'algoritmo__max_iter': [50,100,200],
         'algoritmo__max_depth': [5,10,20],
         'algoritmo__min_samples_leaf': [500],
#          'algoritmo__scoring': ['neg_mean_absolute_error'],
         'algoritmo__l2_regularization': [0,0.25,0.5,0.75,1]}
       ]

# %%
# m = HistGradientBoostingRegressor(learning_rate=0.01, max_iter=50,scoring="neg_mean_absolute_error",
#                                   max_depth=10, min_samples_leaf=500, l2_regularization=0.5)
# m.fit(x,y)
# m.predict(x)

# %%
# m= XGBRegressor(learning_rate=0.01,max_depth=10,reg_alpha=0.1,reg_lambda=0.01,n_estimators=1000,e
#                 scoring="neg_mean_absolute_error" )
# m.fit(x,y)
# m.predict(x)

# %%
# from sklearn.tree import DecisionTreeRegressor
# a= DecisionTreeRegressor(criterion='absolute_error')
# a.fit(x,y)

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
# grid_search = GridSearchCV(estimator= pipe, 
#                            param_grid = grid, 
#                            cv = 3, 
#                            scoring = 'neg_mean_absolute_percentage_error',
#                            verbose = 0,
#                            n_jobs = -1)

# modelo = grid_search.fit(train_x,train_y)

# pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0             0.02          0.00             0.00            0.00
# 352           3.97          0.16             0.01            0.00
# 364           4.50          0.18             0.01            0.00
# 360           7.80          0.13             0.01            0.00
# 348           4.18          0.13             0.01            0.00
# ..             ...           ...              ...             ...
# 301           4.57          0.11             0.01            0.00
# 313           8.24          0.12             0.01            0.00
# 325          11.82          0.59             0.01            0.00
# 217          17.26          0.41             0.01            0.00
# 205          12.85          0.98             0.01            0.00
#
#                                        param_algoritmo  \
# 0                          LinearRegression(n_jobs=-1)
# 352  XGBRegressor(base_score=None, booster=None, co...
# 364  XGBRegressor(base_score=None, booster=None, co...
# 360  XGBRegressor(base_score=None, booster=None, co...
# 348  XGBRegressor(base_score=None, booster=None, co...
# ..                                                 ...
# 301  XGBRegressor(base_score=None, booster=None, co...
# 313  XGBRegressor(base_score=None, booster=None, co...
# 325  XGBRegressor(base_score=None, booster=None, co...
# 217  XGBRegressor(base_score=None, booster=None, co...
# 205  XGBRegressor(base_score=None, booster=None, co...
#
#     param_algoritmo__n_jobs param_algoritmo__max_depth  \
# 0                        -1                        NaN
# 352                      -1                          5
# 364                      -1                          5
# 360                      -1                          5
# 348                      -1                          5
# ..                      ...                        ...
# 301                      -1                         20
# 313                      -1                         20
# 325                      -1                         20
# 217                      -1                         20
# 205                      -1                         20
#
#     param_algoritmo__n_estimators param_algoritmo__learning_rate  \
# 0                             NaN                            NaN
# 352                           500                           0.10
# 364                          1000                           0.10
# 360                          1000                           0.10
# 348                           500                           0.10
# ..                            ...                            ...
# 301                           100                           0.05
# 313                           500                           0.05
# 325                          1000                           0.05
# 217                          1000                           0.03
# 205                           500                           0.03
#
#     param_algoritmo__reg_alpha  ... param_algoritmo__max_iter  \
# 0                          NaN  ...                       NaN
# 352                       0.50  ...                       NaN
# 364                       0.50  ...                       NaN
# 360                          0  ...                       NaN
# 348                          0  ...                       NaN
# ..                         ...  ...                       ...
# 301                       0.10  ...                       NaN
# 313                       0.10  ...                       NaN
# 325                       0.10  ...                       NaN
# 217                       0.10  ...                       NaN
# 205                       0.10  ...                       NaN
#
#     param_algoritmo__min_samples_leaf param_algoritmo__scoring  \
# 0                                 NaN                      NaN
# 352                               NaN                      NaN
# 364                               NaN                      NaN
# 360                               NaN                      NaN
# 348                               NaN                      NaN
# ..                                ...                      ...
# 301                               NaN                      NaN
# 313                               NaN                      NaN
# 325                               NaN                      NaN
# 217                               NaN                      NaN
# 205                               NaN                      NaN
#
#                                                 params split0_test_score  \
# 0    {'algoritmo': LinearRegression(n_jobs=-1), 'al...             -0.24
# 352  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.52
# 364  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.52
# 360  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.57
# 348  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.57
# ..                                                 ...               ...
# 301  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.72
# 313  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.73
# 325  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.73
# 217  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.85
# 205  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.85
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0               -0.14              -0.24            -0.21            0.05
# 352             -0.70              -1.70            -0.97            0.52
# 364             -0.70              -1.70            -0.97            0.52
# 360             -0.74              -1.61            -0.97            0.46
# 348             -0.74              -1.61            -0.97            0.46
# ..                ...                ...              ...             ...
# 301             -1.70              -2.71            -2.71            0.82
# 313             -1.71              -2.72            -2.72            0.82
# 325             -1.71              -2.72            -2.72            0.82
# 217             -1.70              -2.72            -2.76            0.88
# 205             -1.70              -2.72            -2.76            0.88
#
#      rank_test_score
# 0                  1
# 352                2
# 364                2
# 360                4
# 348                5
# ..               ...
# 301              618
# 313              619
# 325              619
# 217              621
# 205              622
#
# [622 rows x 22 columns]

# %% [markdown]
# ####  Con random search

# %%
from  sklearn.model_selection import TimeSeriesSplit
time_cv = TimeSeriesSplit(5, test_size = 30)

# %%
train_x.shape, train_y.shape
# Out:
# ((6065, 10), (6065,))

# %%
random_search = RandomizedSearchCV(estimator = pipe,
                                   param_distributions = grid, 
                                   n_iter = 25, 
                                   cv = time_cv, 
                                   scoring = 'neg_mean_absolute_error', 
                                   verbose = 0,
                                   n_jobs = -1)




modelo = random_search.fit(train_x,train_y)

# %%
z =pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
z
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 16          12.81          3.31             0.01            0.00
# 0            4.68          0.07             0.01            0.01
# 3            2.60          0.25             0.06            0.02
# 5            9.95          0.95             0.01            0.00
# 12           1.01          0.02             0.00            0.00
# 20           4.27          2.13             0.03            0.02
# 6            0.33          0.01             0.02            0.00
# 19          12.83          3.20             0.01            0.02
# 10          25.34          1.47             0.01            0.00
# 13           1.09          0.05             0.01            0.00
# 15           1.64          0.17             0.04            0.00
# 23           5.33          0.32             0.01            0.00
# 7           13.51          1.95             0.01            0.00
# 4           30.73          1.42             0.01            0.00
# 21          42.26         12.03             0.07            0.04
# 11          10.83          0.46             0.01            0.00
# 14          32.45          1.69             0.03            0.04
# 22           6.78          1.01             0.04            0.07
# 9           24.04          0.56             0.01            0.00
# 8           15.38          0.32             0.01            0.00
# 17          83.81          6.57             2.55            4.82
# 18           3.72          0.27             0.08            0.01
# 24           2.73          0.52             0.04            0.01
# 1            0.18          0.03             0.00            0.00
# 2            5.53          0.65             0.00            0.00
#
#    param_algoritmo__reg_lambda param_algoritmo__reg_alpha  \
# 16                        0.01                          1
# 0                            1                          0
# 3                          NaN                        NaN
# 5                         0.10                       0.50
# 12                           1                          0
# 20                         NaN                        NaN
# 6                          NaN                        NaN
# 19                        0.10                          0
# 10                        0.10                       0.50
# 13                        0.10                       0.10
# 15                         NaN                        NaN
# 23                        0.01                       0.10
# 7                            1                       0.50
# 4                            1                          1
# 21                        0.01                          0
# 11                        0.01                       0.10
# 14                        0.01                          0
# 22                        0.01                       0.10
# 9                         0.10                          0
# 8                            1                       0.10
# 17                        0.10                          0
# 18                         NaN                        NaN
# 24                         NaN                        NaN
# 1                          NaN                        NaN
# 2                            1                          0
#
#    param_algoritmo__n_jobs param_algoritmo__n_estimators  \
# 16                      -1                          1000
# 0                       -1                           500
# 3                      NaN                           NaN
# 5                       -1                          1000
# 12                      -1                           100
# 20                     NaN                           NaN
# 6                       -1                            50
# 19                      -1                          1000
# 10                      -1                          1000
# 13                      -1                           100
# 15                     NaN                           NaN
# 23                      -1                           500
# 7                       -1                          1000
# 4                       -1                          1000
# 21                      -1                          1000
# 11                      -1                          1000
# 14                      -1                          1000
# 22                      -1                           500
# 9                       -1                          1000
# 8                       -1                           500
# 17                      -1                           500
# 18                     NaN                           NaN
# 24                     NaN                           NaN
# 1                      NaN                           NaN
# 2                       -1                           100
#
#    param_algoritmo__max_depth param_algoritmo__learning_rate  ...  \
# 16                          5                           0.03  ...
# 0                           5                           0.01  ...
# 3                          10                           0.10  ...
# 5                           5                           0.01  ...
# 12                          5                           0.05  ...
# 20                         20                           0.05  ...
# 6                          15                            NaN  ...
# 19                          5                           0.03  ...
# 10                         20                           0.10  ...
# 13                          5                           0.10  ...
# 15                         10                           0.10  ...
# 23                          5                           0.05  ...
# 7                           5                           0.05  ...
# 4                          10                           0.03  ...
# 21                         10                           0.10  ...
# 11                          5                           0.05  ...
# 14                         10                           0.05  ...
# 22                          5                           0.10  ...
# 9                          10                           0.10  ...
# 8                          10                           0.10  ...
# 17                         20                           0.03  ...
# 18                         20                           0.01  ...
# 24                          5                           0.01  ...
# 1                           5                           0.01  ...
# 2                          20                           0.01  ...
#
#    param_algoritmo__l2_regularization  \
# 16                                NaN
# 0                                 NaN
# 3                                   1
# 5                                 NaN
# 12                                NaN
# 20                               0.50
# 6                                 NaN
# 19                                NaN
# 10                                NaN
# 13                                NaN
# 15                               0.25
# 23                                NaN
# 7                                 NaN
# 4                                 NaN
# 21                                NaN
# 11                                NaN
# 14                                NaN
# 22                                NaN
# 9                                 NaN
# 8                                 NaN
# 17                                NaN
# 18                                  0
# 24                               0.50
# 1                                0.75
# 2                                 NaN
#
#                                                params split0_test_score  \
# 16  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.33
# 0   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -3.22
# 3   {'algoritmo__min_samples_leaf': 500, 'algoritm...             -3.50
# 5   {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.30
# 12  {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -3.27
# 20  {'algoritmo__min_samples_leaf': 500, 'algoritm...             -3.59
# 6   {'algoritmo__n_jobs': -1, 'algoritmo__n_estima...             -3.21
# 19  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.41
# 10  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.10
# 13  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.35
# 15  {'algoritmo__min_samples_leaf': 500, 'algoritm...             -3.55
# 23  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.29
# 7   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -3.30
# 4   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -3.55
# 21  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.59
# 11  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.36
# 14  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.62
# 22  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.48
# 9   {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.41
# 8   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -3.44
# 17  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.52
# 18  {'algoritmo__min_samples_leaf': 500, 'algoritm...             -3.64
# 24  {'algoritmo__min_samples_leaf': 500, 'algoritm...             -3.65
# 1   {'algoritmo__min_samples_leaf': 500, 'algoritm...             -4.07
# 2   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -6.91
#
#    split1_test_score split2_test_score  split3_test_score  split4_test_score  \
# 16             -2.81             -3.25              -3.06              -2.69
# 0              -2.84             -3.32              -3.10              -2.67
# 3              -2.94             -3.27              -2.85              -2.68
# 5              -2.85             -3.41              -3.07              -2.69
# 12             -2.89             -3.39              -3.06              -2.72
# 20             -2.70             -3.51              -3.04              -2.56
# 6              -2.72             -3.41              -3.03              -3.06
# 19             -2.88             -3.37              -3.07              -2.71
# 10             -3.37             -3.12              -2.87              -3.00
# 13             -2.89             -3.35              -3.08              -2.80
# 15             -2.89             -3.38              -2.98              -2.69
# 23             -2.90             -3.47              -3.14              -2.72
# 7              -2.90             -3.36              -3.38              -2.73
# 4              -2.95             -3.15              -3.05              -3.03
# 21             -3.06             -3.24              -3.01              -2.96
# 11             -3.03             -3.63              -3.18              -2.69
# 14             -2.93             -3.30              -3.16              -2.95
# 22             -2.93             -3.56              -3.24              -2.78
# 9              -3.09             -3.04              -3.25              -3.31
# 8              -2.97             -3.54              -3.19              -3.00
# 17             -3.31             -3.30              -3.17              -3.50
# 18             -3.06             -4.08              -3.30              -2.93
# 24             -3.06             -4.07              -3.31              -2.93
# 1              -4.98             -5.43              -4.36              -4.38
# 2              -7.28             -6.89              -6.65              -7.11
#
#     mean_test_score  std_test_score  rank_test_score
# 16            -3.03            0.25                1
# 0             -3.03            0.24                2
# 3             -3.05            0.30                3
# 5             -3.06            0.27                4
# 12            -3.07            0.24                5
# 20            -3.08            0.41                6
# 6             -3.09            0.23                7
# 19            -3.09            0.27                8
# 10            -3.09            0.16                9
# 13            -3.09            0.23               10
# 15            -3.10            0.32               11
# 23            -3.11            0.27               12
# 7             -3.13            0.27               13
# 4             -3.15            0.21               14
# 21            -3.17            0.23               15
# 11            -3.18            0.31               16
# 14            -3.19            0.25               17
# 22            -3.20            0.30               18
# 9             -3.22            0.14               19
# 8             -3.23            0.23               20
# 17            -3.36            0.13               21
# 18            -3.40            0.42               22
# 24            -3.40            0.41               23
# 1             -4.64            0.49               24
# 2             -6.97            0.22               25
#
# [25 rows x 23 columns]

# %%
z.loc[:,['param_algoritmo']]
# Out:
#                                       param_algoritmo
# 16  XGBRegressor(base_score=None, booster=None, co...
# 0   XGBRegressor(base_score=None, booster=None, co...
# 3                     HistGradientBoostingRegressor()
# 5   XGBRegressor(base_score=None, booster=None, co...
# 12  XGBRegressor(base_score=None, booster=None, co...
# 20                    HistGradientBoostingRegressor()
# 6                             RandomForestRegressor()
# 19  XGBRegressor(base_score=None, booster=None, co...
# 10  XGBRegressor(base_score=None, booster=None, co...
# 13  XGBRegressor(base_score=None, booster=None, co...
# 15                    HistGradientBoostingRegressor()
# 23  XGBRegressor(base_score=None, booster=None, co...
# 7   XGBRegressor(base_score=None, booster=None, co...
# 4   XGBRegressor(base_score=None, booster=None, co...
# 21  XGBRegressor(base_score=None, booster=None, co...
# 11  XGBRegressor(base_score=None, booster=None, co...
# 14  XGBRegressor(base_score=None, booster=None, co...
# 22  XGBRegressor(base_score=None, booster=None, co...
# 9   XGBRegressor(base_score=None, booster=None, co...
# 8   XGBRegressor(base_score=None, booster=None, co...
# 17  XGBRegressor(base_score=None, booster=None, co...
# 18                    HistGradientBoostingRegressor()
# 24                    HistGradientBoostingRegressor()
# 1                     HistGradientBoostingRegressor()
# 2   XGBRegressor(base_score=None, booster=None, co...

# %%
# 10 variables: mae mean 3 mae std 3
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, enable_categorical=False,
#                               gamma=0, gpu_id=-1, importance_type=None,
#                               interaction_constraints='', learning_rate=0.025,
#                               max_delta_step=0, max_depth=5, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1000, n_jobs=-1, num_parallel_tree=1,
#                               predictor='auto', random_state=0, reg_alpha=1,
#                               reg_lambda=0.01, scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])

# %%
importance_values = modelo.best_estimator_.steps[0][1].feature_importances_
importance_values

importance_features = train_x.columns.tolist()
importance_features

pd.DataFrame(importance_values.T, index= importance_features,columns=['feature_importance'])
# Out:
#                  feature_importance
# tmax_1_ss                      0.75
# tmin_1_ss                      0.04
# day                            0.02
# prcp_1_ss                      0.03
# awnd_1_ss                      0.02
# wsf2_1_ss                      0.05
# wdf2_1_ss                      0.02
# tmax_mm_7_ss                   0.02
# tmax_mm_6_ss                   0.05
# tmax_mensual_ss                0.01

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = modelo.best_estimator_.predict(val_x)

# %% [markdown]
# ### Evaluar sobre validación

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(val_y, pred)
# Out:
# 2.7665654283453924

# %% [markdown]
# ### Examinar el mejor modelo

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, enable_categorical=False,
#                               gamma=0, gpu_id=-1, importance_type=None,
#                               interaction_constraints='', learning_rate=0.1,
#                               max_delta_step=0, max_depth=5, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1000, n_jobs=-1, num_parallel_tree=1,
#                               predictor='auto', random_state=0, reg_alpha=1,
#                               reg_lambda=1, scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])
