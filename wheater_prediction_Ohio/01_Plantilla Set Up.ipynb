# %% [markdown]
# # SET UP

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## CREAR EL ENTORNO PARA EL PROYECTO

# %% [markdown]
# Prediccion tiempo ohio.
# Data source: https://www.ncei.noaa.gov/access

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import os
import numpy as np
import pandas as pd

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## CREAR EL DIRECTORIO DEL PROYECTO

# %% [markdown]
# ### Definir el directorio raiz donde vamos a crear el proyecto

# %%
raiz = 'C:/proyectos/weather_ohio/'

# %% [markdown]
# ## CREAR LOS DATASETS INICIALES

# %% [markdown]
# Poner los datos originales en la carpeta '/02_Datos/01_Originales'

# %% [markdown]
# ### Importar los datos

# %% [markdown]
# Sustituir el nombre_fichero_datos.

# %%
nombre_fichero_datos = 'ohio_weather.csv'

# %% [markdown]
# Cargar los datos.

# %%
ruta_completa = raiz + '/02_Datos/01_Originales/' + nombre_fichero_datos
print(ruta_completa)
datos = pd.read_csv(ruta_completa,index_col=0)
datos
# Out:
# C:/proyectos/weather_ohio//02_Datos/01_Originales/ohio_weather.csv
#                                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# STATION
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# ...                                      ...       ...        ...        ...
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# USW00014894  WHEELING OHIO CO AIRPORT, WV US  40.16994  -80.64406      364.3
# ...

# %%
#Solo coger datos con mas de un valor
serie_unico = datos.reset_index().nunique()
columnas_utiles = serie_unico[serie_unico>1].index.tolist()

# %%
serie_unico
# Out:
# STATION               1
# NAME                  1
# LATITUDE              1
# LONGITUDE             1
# ELEVATION             1
# DATE               9176
# AWND                 97
# AWND_ATTRIBUTES       2
# FMTM               1040
# FMTM_ATTRIBUTES       2
# PGTM               1275
# PGTM_ATTRIBUTES       1
# PRCP                175
# PRCP_ATTRIBUTES       5
# PSUN                  1
# PSUN_ATTRIBUTES       1
# SNOW                  1
# SNOW_ATTRIBUTES       1
# SNWD                  1
# SNWD_ATTRIBUTES       1
# TAVG                 79
# TAVG_ATTRIBUTES       2
# TMAX                 94
# TMAX_ATTRIBUTES       6
# TMIN                 88
# TMIN_ATTRIBUTES       6
# TSUN                  1
# TSUN_ATTRIBUTES       1
# WDF2                 37
# WDF2_ATTRIBUTES       2
# WDF5                 37
# WDF5_ATTRIBUTES       2
# WSF2                 45
# WSF2_ATTRIBUTES       2
# WSF5                 70
# WSF5_ATTRIBUTES       2
# WT01                  1
# WT01_ATTRIBUTES       1
# ...

# %%
df = datos.reset_index()[columnas_utiles].copy()

# %%
df.sort_values('DATE')
# Out:
#             DATE   AWND AWND_ATTRIBUTES   FMTM FMTM_ATTRIBUTES    PGTM  PRCP  \
# 0     1998-03-26    NaN             NaN    NaN             NaN     NaN   NaN
# 1     1998-03-27    NaN             NaN    NaN             NaN     NaN   NaN
# 2     1998-03-28    NaN             NaN    NaN             NaN     NaN   NaN
# 3     1998-03-29    NaN             NaN    NaN             NaN     NaN   NaN
# 4     1998-04-01  11.63             ,,W  335.0             ,,W   334.0  0.23
# ...          ...    ...             ...    ...             ...     ...   ...
# 9171  2023-05-15   4.92             ,,W    NaN             NaN     NaN  0.00
# 9172  2023-05-16   5.37             ,,W    NaN             NaN     NaN  0.00
# 9173  2023-05-17   8.72             ,,W    NaN             NaN   857.0  0.00
# 9174  2023-05-18   4.70             ,,W    NaN             NaN  2217.0  0.00
# 9175  2023-05-19    NaN             NaN    NaN             NaN     NaN  0.11
#
# ...

# %%
df_train = df.loc[:"2022"]
df_validacion = df.loc["2022":]

# %%
print(f" filas total {df.shape[0]} \n filas train {df_train.shape[0]} \n filas validacion {df_validacion.shape[0]}")
# Out:
#  filas total 9176
#  filas train 8672
#  filas validacion 504

# %% [markdown]
# ### Extraer y reservar el dataset de validación

# %%
raiz
# Out:
# 'C:/proyectos/weather_ohio/'

# %%
nombre_fichero_validacion = 'validacion.csv'

ruta_completa = raiz + '/02_Datos/02_Validacion/' + nombre_fichero_validacion

df_validacion.to_csv(ruta_completa)

# %% [markdown]
# ### Extraer y guardar el dataset de trabajo

# %%
nombre_fichero_trabajo = 'trabajo.csv'

ruta_completa = raiz + '/02_Datos/03_Trabajo/' + nombre_fichero_trabajo

df_train.to_csv(ruta_completa)
